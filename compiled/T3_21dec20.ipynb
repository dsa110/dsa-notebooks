# %%
import glob
import os
import numpy as np
import yaml
import astropy.units as u
from astropy.io import ascii
import os
import matplotlib.pyplot as plt
import json
import subprocess
dir = '21dec20' # enter date string here

# %% [markdown]
# ## Read and plot data

# %%
os.system('cat /mnt/data/dsa110/T2/'+dir+'/*.cand > tmp.dat')
snr,it,itime,mjds,ibox,idm,dm,memb,ibeam = np.loadtxt('tmp.dat').transpose()

# %%
plt.figure(figsize=(12,8))
plt.xlabel('Time (hr)')
plt.ylabel('Beam')
s = snr**3.5
s /= np.min(s)
dmc = dm/np.max(dm)
x1 = 0. # set xlim in hr
x2 = 20. # set xlim in hr
plt.xlim(x1,x2)
plt.scatter(mjds/3600.,ibeam,s=s,alpha=0.5,cmap='jet',c=dmc)
fls = glob.glob('/mnt/data/dsa110/T2/'+dir+'/*.json')
for fl in fls:
    f = open(fl)
    d = json.load(f)  
    snum = int(list(d.keys())[0])
    snum2 = 16*(snum-477)
    val = list(d.values())[0]
    plt.plot([float(val['mjds'])/3600.],[float(val['ibeam'])],'s',markersize=20.,markeredgecolor='black',markerfacecolor='none')
 
# %cd /mnt/data/dsa110/T3/scripts
cmd = ['python', 'gen_catalog.py', dir]
p = subprocess.Popen(cmd, stdout=subprocess.PIPE)
p.wait()
metadata = np.load(dir+'_cat.npz')['metadata']
i = 0
for mm in metadata:
    if float(mm[1])/3600. > x1:
        if float(mm[1])/3600. < x2:
            plt.plot([float(mm[1])/3600.],[float(mm[4])],'s',markersize=20.,markeredgecolor='black',markerfacecolor='none')
            plt.text(float(mm[1])/3600.,float(mm[4]),str(mm[0]),fontsize=10)
            # columns are index, sample number, time (hr), S/N, DM, beam number, list of voltage dumps. 
            print(i,mm[0],float(mm[1])/3600.,mm[2],mm[3],mm[4],mm[5])
            i += 1
# Out:
# /mnt/data/dsa110/T3/scripts
# 0 278874240 5.076888888888889 8.56739 127.158 177 fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out fl_3.out
# 1 286997792 5.224777777777778 8.63137 132.264 135 fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out fl_13.out
# 2 552921104 10.06575 8.54222 910.232 121 fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out fl_14.out
# 3 1026015808 18.678194444444443 9.07443 193.675 76 fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out fl_16.out
# 4 728511920 13.262305555555557 9.08445 122.053 178 fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out fl_15.out
# 5 281437152 5.123555555555555 9.02535 183.42 11 fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out fl_5.out
# 6 286681072 5.219 8.86088 142.48 133 fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out fl_12.out
# 7 281055520 5.116611111111111 8.60359 380.358 180 fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out fl_4.out
# 8 278034320 5.061611111111111 9.69167 168.053 74 fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out fl_2.out
# 9 272615840 4.962972222222223 9.52052 142.48 134 fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out fl_0.out
# 10 281807504 5.130277777777778 9.93166 203.94 100 fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out fl_6.out
# 11 282974720 5.151527777777778 8.67461 101.649 21 fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out fl_8.out
# 12 285068048 5.189638888888889 8.83453 157.818 35 fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out fl_11.out
# 13 283465280 5.160472222222222 8.9375 116.95 25 fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out fl_9.out
# 14 277217616 5.046722222222223 8.52369 168.053 155 fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out fl_1.out
# 15 284435504 5.178138888888888 9.27081 162.935 204 fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out fl_10.out
# 16 282233120 5.138027777777778 8.8568 127.158 189 fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out fl_7.out

# %% [markdown]
# ## Now run through baseband processing for any interesting candidates

# %%
# This copies the latest bf weights and the data files
cmd = ['./cp_weights_corr22.bash']
p = subprocess.Popen(cmd, stdout=subprocess.PIPE)
for line in p.stdout:
    print(line)
p.wait()
os.system('./cp_corr22.bash '+metadata[2][5]) # edit first index to match line number above
# Out:
# 0

# %%
# This forms the coherent beam
os.system('./run_bf_corr22.bash '+metadata[2][4])
# Out:
# 256

# %%
# This copies the data across
os.system('cd ~/data; scp ubuntu@corr22.sas.pvt:./data/spliced.fil .')
# Out:
# 0

# %%
# The rest is up to you! You can use sigpyproc to plot up stuff

from sigpyproc.Readers import FilReader
# %cd /home/user/data
f = FilReader('spliced.fil')
f.header
# Out:
# /mnt/data/dsa110
# {'telescope_id': 66,
#  'az_start': 0.0,
#  'nbits': 8,
#  'source_name': 'source',
#  'data_type': 1,
#  'nchans': 6144,
#  'machine_id': 99,
#  'tsamp': 3.2768e-05,
#  'foff': -0.03051757812,
#  'nbeams': 190,
#  'fch1': 1498.75,
#  'tstart': 55000.0,
#  'nifs': 1,
#  'hdrlen': 250,
#  'filelen': 754974970,
#  'nbytes': 754974720,
#  'nsamples': 122880,
#  'filename': 'spliced.fil',
#  'basename': 'spliced',
#  'extension': '.fil',
#  'bandwidth': 187.49999996928,
#  'ftop': 1498.76525878906,
#  'fbottom': 1311.26525881978,
#  'fcenter': 1405.01525880442,
#  'tobs': 4.0265318400000005,
#  'src_raj': 0,
#  'src_dej': 0,
#  'ra': '00:00:00.0000',
#  'dec': '00:00:00.0000',
#  'ra_rad': 0.0,
#  'dec_rad': 0.0,
#  'ra_deg': 0.0,
#  'dec_deg': 0.0,
#  'obs_date': '17/06/2009',
#  'obs_time': '00:00:00.00000',
#  'dtype': '<u1'}

# %%
ts = f.dedisperse(343.6)
fts = ts.applyBoxcar(256)
x = np.arange(len(fts))*f.header['tsamp']*1e3
plt.figure(figsize=(12,4.))
plt.plot(x,fts)
plt.xlabel('Time (ms)')
plt.ylabel('power')
#plt.xlim(400.,800.)
# Out:
# Filterbank reading plan:
# ------------------------
# Called on file:        spliced.fil
# Called by:             dedisperse
# Number of samps:       122880
# Number of reads:       19
# Nsamps per read:       11868
# Nsamps of final read:  10134
# Nsamps to skip back:   5934
#
# Execution time: 1.229290 seconds
# Text(0,0.5,'power')

# %%
dnam = f.downsample(tfactor=32,ffactor=16,filename='scrunch.fil')
d = FilReader(dnam)
da = d.readBlock(0,d.header['nsamples'])
# Out:
# Filterbank reading plan:
# ------------------------
# Called on file:        spliced.fil
# Called by:             downsample
# Number of samps:       122880
# Number of reads:       240
# Nsamps per read:       512
# Nsamps of final read:  512
# Nsamps to skip back:   0
#
# Execution time: 1.190435 seconds

# %%
plt.figure(figsize=(10,7))
mnspec = da.mean(axis=1)
for i in range(da.shape[1]):
    da[:,i] -= mnspec
da = np.reshape(da,(int(da.shape[0]/4),4,da.shape[1])).mean(axis=1)
plt.imshow(da,origin='lower',aspect='auto',cmap='coolwarm',vmin=-2.*np.std(da),vmax=2.*np.std(da))
